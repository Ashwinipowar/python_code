# %%
print("hi")
# Out:
# hi

# %%
n=5
for i in range(1,n+1):
    for j in range(1,i+1):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=5
for i in range(n,0,-1):
    for j in range(n,0,-1):
        print("*",end=" ")
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *
